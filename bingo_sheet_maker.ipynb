# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
bingo_df = pd.read_csv('bingo.csv', sep=';')

# %%
bingo_df.columns
# Out:
# Index([u'text', u'odds'], dtype='object')

# %%
ones = bingo_df[bingo_df.odds == 1].text.tolist()
twos = bingo_df[bingo_df.odds == 2].text.tolist()
threes= bingo_df[bingo_df.odds == 3].text.tolist()

# %%
from random import randint

# %%
rand = []
for i in range(25):
    rand.append(randint(1,3))
rand = np.array(rand)
rand[12]=0
rand.reshape(5,5)
# Out:
# array([[2, 1, 2, 1, 2],
#        [3, 2, 2, 3, 3],
#        [3, 1, 0, 1, 2],
#        [1, 1, 3, 3, 1],
#        [2, 3, 1, 2, 1]])

# %%
num_ones = len(np.argwhere(rand == 1))
num_twos = len(np.argwhere(rand == 2))
num_threes = len(np.argwhere(rand == 3))
text1 = np.random.choice(ones, num_ones, replace=False )
text2 = np.random.choice(twos, num_twos, replace=False)
text3 = np.random.choice(threes, num_threes, replace=False)

# %%
bingo_sheet = np.empty(25, dtype='|S1000')

# %%
used_list = ['babalabl']
used_list = np.array(used_list)

for i,element in enumerate(rand):
    #print(i, element)
    if element == 0:
        text=np.array("(free square) Justyn, Vik and Stu aren't at CAPER")
    if element == 1:
        text = 'babalabl'
        while np.any(used_list == text):
            text = random.choice(ones)  

    if element == 2:
        text = 'babalabl'
        while np.any(used_list == text):
            text = random.choice(twos)  

    if element == 3:
        text = 'babalabl'
        while np.any(used_list == text):
            text = random.choice(threes)  
    
    used_list = np.append(used_list, text)
    #print(text)
    #print(type(text))
    #bingo_sheet.append(text)
    bingo_sheet[i] = text
    
#bingo_sheet = np.array(bingo_sheet)
#bingo_sheet.reshape(5,5)
bingo_sheet
# Out:
# array(['paper is on exo planets', 'savory "cakes"',
#        'reference to news/social media coverage of topic in paper',
#        'it takes 3 tries to get the lights',
#        'the projector or computer does not work',
#        'Richard does the head thing',
#        'noone but clive prints and brings along the paper',
#        'Section/caveat/reference/plot the referee clearly insisted the authors put in',
#        'someone leaves early', 'nothing you would describe as "a cake"',
#        'Pablo has announcement about some IT system', 'Paul says "myeah"',
#        "(free square) Justyn, Vik and Stu aren't at CAPER",
#        'Crumbs everywhere on the table',
#        "someone notices we're playing bingo", 'Paul is late at caper',
#        'someone on the paper collaborates with someone in the room',
#        'Someone starts talking and is immediatly spoken over',
#        'speaker accidentally changes slides or goes in wrong direction',
#        'Simon talks about the IMF', 'talk is written in google sheets',
#        'arxiv paper not yet published', 'Justyn IS at caper',
#        'Cakes are from Sainsburys',
#        'James M asks a question about to be answered'],
#       dtype='|S1000')

# %%
bingo_sheet = bingo_sheet.reshape(5,5)

# %%
text=np.array("(free square) justyn Vik and stu aren't  at caper")

# %%
text.tostring()
# Out:
# "(free square) justyn Vik and stu aren't  at caper"

# %%
#np.rand.choice(bingo_df.text.as_matrix(), p = ([4]-bingo_df.odds.as_matrix())

# %%
bingo_sheet.shape
# Out:
# (5, 5)

# %%
import textwrap

# %%
f, ax = plt.subplots(5,5, figsize = (20,20))
plt.subplots_adjust(hspace=0, wspace=0)
#for axis in ax:
#    axis.xaxis.set_visible(False)

for i in range(5):
    for j in range(5):
        mytext = bingo_sheet[i,j]
        mytext = textwrap.fill(mytext, 17)
        """
        mytext = mytext.split()
        total_char = 0
        lines = 1
        inds=[]
        for word_index in len(mytext):
            total_char += len(mytex[word_index])
            if total_char > lines*20:
                inds.append(word_index)
        
        inds.reverse()
        for ind in inds:
            wrappedtext = mytext.insert()
                
        #if len(mytext) > 20:
        #    mytext = "\n".join([mytext[i:i+20] for i in range(0, len(mytext), 20)])
        """    
        #print mytext
        ax[i,j].text(0.1, 0.4, mytext, wrap=True, fontsize=18, transform=ax[i,j].transAxes)
        ax[i,j].xaxis.set_visible(False)
        ax[i,j].yaxis.set_visible(False)
